# %%
import pandas as pd, requests, json
import os

# %%
 # generate path to csv
csv_path = os.path.join('NIELSEN_VOD_VIEWING_HABITS-V4.CSV')
json_converter = pd.read_csv(csv_path)

# %%
# turn the json data into a dataframe and see how many rows and what columns we have
df = pd.DataFrame(json_converter)
print('We have {} rows'.format(len(df)))
str(df.columns.tolist())
# Out:
# We have 9865 rows
# "['row', 'age', 'username', 'gender', 'city', 'state', 'zip', 'lat', 'lng', 'freq', 'services', 'hulu', 'youtube', 'Apple TV+', 'FX', 'netflix', 'fuboTV', 'amazon', 'PlutoTV', 'Discovery+', 'Starz', 'Showtime', 'Philo', 'Crackle', 'CBS All Access', 'IMDb TV', 'Disney+', 'HBO MAX', 'NBC', 'Rent or Buy', 'FOX', 'Peacock', 'Tubi']"

# %%
# convert lat-long to floats and change services from ALL CAPS to regular capitalization
df['latitude'] = json_converter['lat'].astype(float)
df['longitude'] = json_converter['lng'].astype(float)

# %%
# we don't need all those columns - only keep useful ones
cols = ['age','latitude', 'longitude','services']
df_subset = df[cols]

# %%
# drop any rows that lack lat/long data
df_geo = df_subset.dropna(subset=['latitude', 'longitude'], axis=0, inplace=False)

print('We have {} geotagged rows'.format(len(df_geo)))
df_geo.tail()
# Out:
# We have 9515 geotagged rows
#       age  latitude  longitude                                        services
# 9860   76   46.0905  -100.6516                     {'Apple TV+': 1, 'hulu': 1}
# 9861   18   32.8929   -80.0458         {'youtube': 1, 'hulu': 1, 'netflix': 1}
# 9862   28   42.6526   -73.7562  {'Showtime': 1, 'netflix': 1, 'Discovery+': 1}
# 9863   58   40.6612   -91.5745                                  {'youtube': 1}
# 9864   66   40.0826   -79.8501                    {'youtube': 1, 'netflix': 1}

# %%
def df_to_geojson(df, properties, lat='latitude', lon='longitude'):
    # create a new python dict to contain our geojson data, using geojson format
    geojson = {'type':'FeatureCollection', 'features':[]}

    # loop through each row in the dataframe and convert each row to geojson format
    for _, row in df.iterrows():
        # create a feature template to fill in
        feature = {'type':'Feature',
                   'properties':{},
                   'geometry':{'type':'Point',
                               'coordinates':[]}}

        # fill in the coordinates
        feature['geometry']['coordinates'] = [row[lon],row[lat]]

        # for each column, get the value and add it as a new feature property
        for prop in properties:
            feature['properties'][prop] = row[prop]
        
        # add this feature (aka, converted dataframe row) to the list of features inside our dict
        geojson['features'].append(feature)
    
    return geojson

# %%
cols = ['age','latitude', 'longitude','services']
geojson = df_to_geojson(df_geo, cols)

# %%
import IPython
IPython.display.display({'application/geo+json': geojson}, raw=True)
geojson
# Out:
# {'type': 'FeatureCollection',
#  'features': [{'type': 'Feature',
#    'properties': {'age': 62,
#     'latitude': 39.2564,
#     'longitude': -119.9521,
#     'services': "{'hulu': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-119.9521, 39.2564]}},
#   {'type': 'Feature',
#    'properties': {'age': 60,
#     'latitude': 35.7252,
#     'longitude': -92.5575,
#     'services': "{'youtube': 1, 'Apple TV+': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-92.5575, 35.7252]}},
#   {'type': 'Feature',
#    'properties': {'age': 34,
#     'latitude': 32.2143,
#     'longitude': -82.4762,
#     'services': "{'hulu': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-82.4762, 32.2143]}},
#   {'type': 'Feature',
#    'properties': {'age': 73,
#     'latitude': 34.1387,
#     'longitude': -87.3974,
#     'services': "{'FX': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-87.3974, 34.1387]}},
#   {'type': 'Feature',
#    'properties': {'age': 46,
#     'latitude': 38.9907,
#     'longitude': -77.0261,
#     'services': "{'hulu': 1, 'netflix': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-77.0261, 38.9907]}},
#   {'type': 'Feature',
#    'properties': {'age': 71,
#     'latitude': 35.852,
#     'longitude': -78.6841,
#     'services': "{'youtube': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-78.6841, 35.852]}},
#   {'type': 'Feature',
#    'properties': {'age': 66,
#     'latitude': 33.2052,
#     'longitude': -82.6817,
#     'services': "{'fuboTV': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-82.6817, 33.2052]}},
#   {'type': 'Feature',
#    'properties': {'age': 26,
#     'latitude': 33.2293,
#     'longitude': -86.825,
#     'services': "{'hulu': 1, 'netflix': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-86.825, 33.2293]}},
#   {'type': 'Feature',
#    'properties': {'age': 59,
#     'latitude': 63.5436,
#     'longitude': -149.9867,
#     'services': "{'hulu': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-149.9867, 63.5436]}},
#   {'type': 'Feature',
#    'properties': {'age': 64,
#     'latitude': 36.5415,
#     'longitude': -81.4468,
#     'services': "{'amazon': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-81.4468, 36.5415]}},
#   {'type': 'Feature',
#    'properties': {'age': 19,
#     'latitude': 33.5604,
#     'longitude': -81.7196,
#     'services': "{'youtube': 1, 'hulu': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-81.7196, 33.5604]}},
#   {'type': 'Feature',
#    'properties': {'age': 79,
#     'latitude': 28.4429,
#     'longitude': -81.4026,
#     'services': "{'netflix': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-81.4026, 28.4429]}},
#   {'type': 'Feature',
#    'properties': {'age': 64,
#     'latitude': 46.7949,
#     'longitude': -88.6251,
#     'services': "{'hulu': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-88.6251, 46.7949]}},
#   {'type': 'Feature',
#    'properties': {'age': 48,
#     'latitude': 34.8497,
#     'longitude': -82.4538,
#     'services': "{'hulu': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-82.4538, 34.8497]}},
#   {'type': 'Feature',
#    'properties': {'age': 27,
#     'latitude': 44.5838,
#     'longitude': -102.0229,
#     'services': "{'netflix': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-102.0229, 44.5838]}},
#   {'type': 'Feature',
#    'properties': {'age': 31,
#     'latitude': 42.2055,
#     'longitude': -71.8391,
#     'services': "{'youtube': 1, 'netflix': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-71.8391, 42.2055]}},
#   {'type': 'Feature',
#    'properties': {'age': 56,
#     'latitude': 34.3804,
#     'longitude': -81.7773,
#     'services': "{'youtube': 1, 'amazon': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-81.7773, 34.3804]}},
#   {'type': 'Feature',
#    'properties': {'age': 74,
#     'latitude': 40.4801,
#     'longitude': -78.7263,
#     'services': "{'netflix': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-78.7263, 40.4801]}},
#   {'type': 'Feature',
#    'properties': {'age': 77,
#     'latitude': 44.2774,
#     'longitude': -75.8496,
#     'services': "{'PlutoTV': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-75.8496, 44.2774]}},
#   {'type': 'Feature',
#    'properties': {'age': 21,
#     'latitude': 44.652,
#     'longitude': -123.1333,
#     'services': "{'hulu': 1, 'youtube': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-123.1333, 44.652]}},
#   {'type': 'Feature',
#    'properties': {'age': 39,
#     'latitude': 43.0552,
#     'longitude': -75.8768,
#     'services': "{'youtube': 1, 'netflix': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-75.8768, 43.0552]}},
#   {'type': 'Feature',
#    'properties': {'age': 67,
#     'latitude': 31.222,
#     'longitude': -81.4826,
#     'services': "{'fuboTV': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-81.4826, 31.222]}},
#   {'type': 'Feature',
#    'properties': {'age': 46,
#     'latitude': 29.2659,
#     'longitude': -89.3761,
#     'services': "{'Discovery+': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-89.3761, 29.2659]}},
#   {'type': 'Feature',
#    'properties': {'age': 31,
#     'latitude': 40.4344,
#     'longitude': -80.0248,
#     'services': "{'netflix': 1, 'youtube': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-80.0248, 40.4344]}},
#   {'type': 'Feature',
#    'properties': {'age': 69,
#     'latitude': 41.18600000000001,
#     'longitude': -77.3162,
#     'services': "{'amazon': 1, 'netflix': 1}"},
#    'geometry': {'type': 'Point',
#     'coordinates': [-77.3162, 41.18600000000001]}},
#   {'type': 'Feature',
#    'properties': {'age': 67,
#     'latitude': 38.5981,
#     'longitude': -121.2153,
#     'services': "{'youtube': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-121.2153, 38.5981]}},
#   {'type': 'Feature',
#    'properties': {'age': 69,
#     'latitude': 38.8933,
#     'longitude': -77.0146,
#     'services': "{'youtube': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-77.0146, 38.8933]}},
#   {'type': 'Feature',
#    'properties': {'age': 27,
#     'latitude': 42.4101,
#     'longitude': -74.8987,
#     'services': "{'amazon': 1, 'hulu': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-74.8987, 42.4101]}},
#   {'type': 'Feature',
#    'properties': {'age': 53,
#     'latitude': 44.9585,
#     'longitude': -94.0552,
#     'services': "{'hulu': 1, 'netflix': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-94.0552, 44.9585]}},
#   {'type': 'Feature',
#    'properties': {'age': 31,
#     'latitude': 36.2404,
#     'longitude': -80.2934,
#     'services': "{'youtube': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-80.2934, 36.2404]}},
#   {'type': 'Feature',
#    'properties': {'age': 74,
#     'latitude': 42.1646,
#     'longitude': -93.5063,
#     'services': "{'netflix': 1, 'youtube': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-93.5063, 42.1646]}},
#   {'type': 'Feature',
#    'properties': {'age': 40,
#     'latitude': 46.5223,
#     'longitude': -67.863,
#     'services': "{'fuboTV': 1, 'netflix': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-67.863, 46.5223]}},
#   {'type': 'Feature',
#    'properties': {'age': 52,
#     'latitude': 30.1854,
#     'longitude': -90.8631,
#     'services': "{'Starz': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-90.8631, 30.1854]}},
#   {'type': 'Feature',
#    'properties': {'age': 61,
#     'latitude': 35.1556,
#     'longitude': -89.7762,
#     'services': "{'youtube': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-89.7762, 35.1556]}},
#   {'type': 'Feature',
#    'properties': {'age': 73,
#     'latitude': 30.5159,
#     'longitude': -91.0804,
#     'services': "{'Showtime': 1, 'youtube': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-91.0804, 30.5159]}},
#   {'type': 'Feature',
#    'properties': {'age': 51,
#     'latitude': 39.471,
#     'longitude': -87.4009,
#     'services': "{'youtube': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-87.4009, 39.471]}},
#   {'type': 'Feature',
#    'properties': {'age': 56,
#     'latitude': 29.834,
#     'longitude': -95.4342,
#     'services': "{'Philo': 1, 'netflix': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-95.4342, 29.834]}},
#   {'type': 'Feature',
#    'properties': {'age': 74,
#     'latitude': 36.8388,
#     'longitude': -83.8329,
#     'services': "{'youtube': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-83.8329, 36.8388]}},
#   {'type': 'Feature',
#    'properties': {'age': 27,
#     'latitude': 48.7788,
#     'longitude': -104.56,
#     'services': "{'netflix': 1, 'Crackle': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-104.56, 48.7788]}},
#   {'type': 'Feature',
#    'properties': {'age': 19,
#     'latitude': 39.9169,
#     'longitude': -89.6891,
#     'services': "{'Starz': 1, 'netflix': 1, 'amazon': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-89.6891, 39.9169]}},
#   {'type': 'Feature',
#    'properties': {'age': 58,
#     'latitude': 38.0768,
#     'longitude': -79.3619,
#     'services': "{'youtube': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-79.3619, 38.0768]}},
#   {'type': 'Feature',
#    'properties': {'age': 26,
#     'latitude': 44.1755,
#     'longitude': -122.1217,
#     'services': "{'hulu': 1, 'youtube': 1, 'netflix': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-122.1217, 44.1755]}},
#   {'type': 'Feature',
#    'properties': {'age': 47,
#     'latitude': 35.6129,
#     'longitude': -79.3726,
#     'services': "{'amazon': 1, 'FX': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-79.3726, 35.6129]}},
#   {'type': 'Feature',
#    'properties': {'age': 51,
#     'latitude': 21.4061,
#     'longitude': -157.9609,
#     'services': "{'netflix': 1, 'Philo': 1, 'CBS All Access': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-157.9609, 21.4061]}},
#   {'type': 'Feature',
#    'properties': {'age': 35,
#     'latitude': 38.8388,
#     'longitude': -104.8145,
#     'services': "{'youtube': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-104.8145, 38.8388]}},
#   {'type': 'Feature',
#    'properties': {'age': 27,
#     'latitude': 38.8933,
#     'longitude': -77.0146,
#     'services': "{'netflix': 1, 'hulu': 1, 'youtube': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-77.0146, 38.8933]}},
#   {'type': 'Feature',
#    'properties': {'age': 43,
#     'latitude': 32.0775,
#     'longitude': -82.4825,
#     'services': "{'hulu': 1, 'Discovery+': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-82.4825, 32.0775]}},
#   {'type': 'Feature',
#    'properties': {'age': 51,
#     'latitude': 41.8142,
#     'longitude': -74.9824,
#     'services': "{'fuboTV': 1, 'hulu': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-74.9824, 41.8142]}},
#   {'type': 'Feature',
#    'properties': {'age': 48,
#     'latitude': 41.0638,
#     'longitude': -81.52,
#     'services': "{'youtube': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-81.52, 41.0638]}},
#   {'type': 'Feature',
#    'properties': {'age': 52,
#     'latitude': 33.8196,
#     'longitude': -98.26,
#     'services': "{'netflix': 1, 'IMDb TV': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-98.26, 33.8196]}},
#   {'type': 'Feature',
#    'properties': {'age': 64,
#     'latitude': 39.0858,
#     'longitude': -95.6867,
#     'services': "{'netflix': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-95.6867, 39.0858]}},
#   {'type': 'Feature',
#    'properties': {'age': 31,
#     'latitude': 38.6095,
#     'longitude': -76.6003,
#     'services': "{'Apple TV+': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-76.6003, 38.6095]}},
#   {'type': 'Feature',
#    'properties': {'age': 37,
#     'latitude': 31.7486,
#     'longitude': -97.8113,
#     'services': "{'netflix': 1, 'youtube': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-97.8113, 31.7486]}},
#   {'type': 'Feature',
#    'properties': {'age': 40,
#     'latitude': 41.6619,
#     'longitude': -78.7978,
#     'services': "{'amazon': 1, 'fuboTV': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-78.7978, 41.6619]}},
#   {'type': 'Feature',
#    'properties': {'age': 77,
#     'latitude': 46.4173,
#     'longitude': -91.811,
#     'services': "{'netflix': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-91.811, 46.4173]}},
#   {'type': 'Feature',
#    'properties': {'age': 57,
#     'latitude': 34.0033,
#     'longitude': -117.445,
#     'services': "{'hulu': 1, 'Disney+': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-117.445, 34.0033]}},
#   {'type': 'Feature',
#    'properties': {'age': 25,
#     'latitude': 34.4482,
#     'longitude': -86.9242,
#     'services': "{'Discovery+': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-86.9242, 34.4482]}},
#   {'type': 'Feature',
#    'properties': {'age': 57,
#     'latitude': 29.9546,
#     'longitude': -90.0751,
#     'services': "{'amazon': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-90.0751, 29.9546]}},
#   {'type': 'Feature',
#    'properties': {'age': 72,
#     'latitude': 37.2187,
#     'longitude': -83.4974,
#     'services': "{'Philo': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-83.4974, 37.2187]}},
#   {'type': 'Feature',
#    'properties': {'age': 34,
#     'latitude': 31.6209,
#     'longitude': -83.2498,
#     'services': "{'Starz': 1, 'HBO MAX': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-83.2498, 31.6209]}},
#   {'type': 'Feature',
#    'properties': {'age': 38,
#     'latitude': 41.2065,
#     'longitude': -74.5381,
#     'services': "{'netflix': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-74.5381, 41.2065]}},
#   {'type': 'Feature',
#    'properties': {'age': 51,
#     'latitude': 30.8667,
#     'longitude': -85.1153,
#     'services': "{'netflix': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-85.1153, 30.8667]}},
#   {'type': 'Feature',
#    'properties': {'age': 27,
#     'latitude': 41.7167,
#     'longitude': -73.9928,
#     'services': "{'Disney+': 1, 'NBC': 1, 'Showtime': 1, 'amazon': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-73.9928, 41.7167]}},
#   {'type': 'Feature',
#    'properties': {'age': 63,
#     'latitude': 35.2944,
#     'longitude': -118.9052,
#     'services': "{'hulu': 1, 'netflix': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-118.9052, 35.2944]}},
#   {'type': 'Feature',
#    'properties': {'age': 48,
#     'latitude': 39.5172,
#     'longitude': -94.7664,
#     'services': "{'amazon': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-94.7664, 39.5172]}},
#   {'type': 'Feature',
#    'properties': {'age': 70,
#     'latitude': 41.2477,
#     'longitude': -87.648,
#     'services': "{'netflix': 1, 'hulu': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-87.648, 41.2477]}},
#   {'type': 'Feature',
#    'properties': {'age': 55,
#     'latitude': 34.3823,
#     'longitude': -90.209,
#     'services': "{'netflix': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-90.209, 34.3823]}},
#   {'type': 'Feature',
#    'properties': {'age': 29,
#     'latitude': 35.2625,
#     'longitude': -116.6966,
#     'services': "{'Showtime': 1, 'youtube': 1, 'PlutoTV': 1, 'netflix': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-116.6966, 35.2625]}},
#   {'type': 'Feature',
#    'properties': {'age': 78,
#     'latitude': 39.1092,
#     'longitude': -84.6108,
#     'services': "{'Starz': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-84.6108, 39.1092]}},
#   {'type': 'Feature',
#    'properties': {'age': 51,
#     'latitude': 41.0002,
#     'longitude': -98.6165,
#     'services': "{'netflix': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-98.6165, 41.0002]}},
#   {'type': 'Feature',
#    'properties': {'age': 32,
#     'latitude': 38.9568,
#     'longitude': -75.8848,
#     'services': "{'netflix': 1, 'HBO MAX': 1, 'amazon': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-75.8848, 38.9568]}},
#   {'type': 'Feature',
#    'properties': {'age': 77,
#     'latitude': 33.9152,
#     'longitude': -87.3074,
#     'services': "{'youtube': 1, 'netflix': 1, 'hulu': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-87.3074, 33.9152]}},
#   {'type': 'Feature',
#    'properties': {'age': 22,
#     'latitude': 34.6834,
#     'longitude': -82.8374,
#     'services': "{'hulu': 1, 'youtube': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-82.8374, 34.6834]}},
#   {'type': 'Feature',
#    'properties': {'age': 39,
#     'latitude': 30.0565,
#     'longitude': -95.1051,
#     'services': "{'amazon': 1, 'youtube': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-95.1051, 30.0565]}},
#   {'type': 'Feature',
#    'properties': {'age': 62,
#     'latitude': 38.8808,
#     'longitude': -77.1129,
#     'services': "{'Rent or Buy': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-77.1129, 38.8808]}},
#   {'type': 'Feature',
#    'properties': {'age': 22,
#     'latitude': 34.7928,
#     'longitude': -101.5471,
#     'services': "{'youtube': 1, 'Crackle': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-101.5471, 34.7928]}},
#   {'type': 'Feature',
#    'properties': {'age': 63,
#     'latitude': 40.377,
#     'longitude': -108.399,
#     'services': "{'FOX': 1, 'youtube': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-108.399, 40.377]}},
#   {'type': 'Feature',
#    'properties': {'age': 76,
#     'latitude': 47.9685,
#     'longitude': -100.5209,
#     'services': "{'youtube': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-100.5209, 47.9685]}},
#   {'type': 'Feature',
#    'properties': {'age': 69,
#     'latitude': 32.5889,
#     'longitude': -116.6192,
#     'services': "{'amazon': 1, 'netflix': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-116.6192, 32.5889]}},
#   {'type': 'Feature',
#    'properties': {'age': 69,
#     'latitude': 36.4155,
#     'longitude': -90.587,
#     'services': "{'youtube': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-90.587, 36.4155]}},
#   {'type': 'Feature',
#    'properties': {'age': 40,
#     'latitude': 38.3357,
#     'longitude': -81.8476,
#     'services': "{'amazon': 1, 'netflix': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-81.8476, 38.3357]}},
#   {'type': 'Feature',
#    'properties': {'age': 63,
#     'latitude': 29.834,
#     'longitude': -95.4342,
#     'services': "{'Philo': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-95.4342, 29.834]}},
#   {'type': 'Feature',
#    'properties': {'age': 24,
#     'latitude': 34.0197,
#     'longitude': -117.9587,
#     'services': "{'youtube': 1, 'netflix': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-117.9587, 34.0197]}},
#   {'type': 'Feature',
#    'properties': {'age': 23,
#     'latitude': 38.8933,
#     'longitude': -77.0146,
#     'services': "{'youtube': 1, 'netflix': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-77.0146, 38.8933]}},
#   {'type': 'Feature',
#    'properties': {'age': 43,
#     'latitude': 34.2198,
#     'longitude': -111.2878,
#     'services': "{'hulu': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-111.2878, 34.2198]}},
#   {'type': 'Feature',
#    'properties': {'age': 39,
#     'latitude': 36.0997,
#     'longitude': -87.7991,
#     'services': "{'netflix': 1, 'youtube': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-87.7991, 36.0997]}},
#   {'type': 'Feature',
#    'properties': {'age': 42,
#     'latitude': 35.0719,
#     'longitude': -92.1832,
#     'services': "{'netflix': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-92.1832, 35.0719]}},
#   {'type': 'Feature',
#    'properties': {'age': 46,
#     'latitude': 37.0876,
#     'longitude': -81.759,
#     'services': "{'hulu': 1, 'youtube': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-81.759, 37.0876]}},
#   {'type': 'Feature',
#    'properties': {'age': 57,
#     'latitude': 39.7294,
#     'longitude': -104.8319,
#     'services': "{'Crackle': 1, 'netflix': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-104.8319, 39.7294]}},
#   {'type': 'Feature',
#    'properties': {'age': 23,
#     'latitude': 41.8603,
#     'longitude': -95.6257,
#     'services': "{'netflix': 1, 'youtube': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-95.6257, 41.8603]}},
#   {'type': 'Feature',
#    'properties': {'age': 69,
#     'latitude': 38.3498,
#     'longitude': -81.6326,
#     'services': "{'amazon': 1, 'CBS All Access': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-81.6326, 38.3498]}},
#   {'type': 'Feature',
#    'properties': {'age': 53,
#     'latitude': 41.9089,
#     'longitude': -71.4348,
#     'services': "{'amazon': 1, 'hulu': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-71.4348, 41.9089]}},
#   {'type': 'Feature',
#    'properties': {'age': 27,
#     'latitude': 40.4821,
#     'longitude': -96.9757,
#     'services': "{'youtube': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-96.9757, 40.4821]}},
#   {'type': 'Feature',
#    'properties': {'age': 56,
#     'latitude': 42.0562,
#     'longitude': -76.348,
#     'services': "{'netflix': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-76.348, 42.0562]}},
#   {'type': 'Feature',
#    'properties': {'age': 43,
#     'latitude': 38.3309,
#     'longitude': -123.0373,
#     'services': "{'Philo': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-123.0373, 38.3309]}},
#   {'type': 'Feature',
#    'properties': {'age': 34,
#     'latitude': 46.755,
#     'longitude': -68.0964,
#     'services': "{'netflix': 1, 'youtube': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-68.0964, 46.755]}},
#   {'type': 'Feature',
#    'properties': {'age': 51,
#     'latitude': 39.0401,
#     'longitude': -94.4951,
#     'services': "{'hulu': 1, 'Peacock': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-94.4951, 39.0401]}},
#   {'type': 'Feature',
#    'properties': {'age': 59,
#     'latitude': 41.2586,
#     'longitude': -95.9378,
#     'services': "{'fuboTV': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-95.9378, 41.2586]}},
#   {'type': 'Feature',
#    'properties': {'age': 78,
#     'latitude': 32.5381,
#     'longitude': -98.4219,
#     'services': "{'amazon': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-98.4219, 32.5381]}},
#   {'type': 'Feature',
#    'properties': {'age': 71,
#     'latitude': 31.7575,
#     'longitude': -96.8944,
#     'services': "{'Philo': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-96.8944, 31.7575]}},
#   {'type': 'Feature',
#    'properties': {'age': 27,
#     'latitude': 41.4759,
#     'longitude': -120.1516,
#     'services': "{'Starz': 1, 'netflix': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-120.1516, 41.4759]}},
#   {'type': 'Feature',
#    'properties': {'age': 74,
#     'latitude': 44.4461,
#     'longitude': -71.8676,
#     'services': "{'amazon': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-71.8676, 44.4461]}},
#   {'type': 'Feature',
#    'properties': {'age': 34,
#     'latitude': 29.6486,
#     'longitude': -81.6376,
#     'services': "{'netflix': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-81.6376, 29.6486]}},
#   {'type': 'Feature',
#    'properties': {'age': 35,
#     'latitude': 40.2193,
#     'longitude': -89.2852,
#     'services': "{'hulu': 1, 'youtube': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-89.2852, 40.2193]}},
#   {'type': 'Feature',
#    'properties': {'age': 44,
#     'latitude': 31.5851,
#     'longitude': -93.4641,
#     'services': "{'youtube': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-93.4641, 31.5851]}},
#   {'type': 'Feature',
#    'properties': {'age': 33,
#     'latitude': 39.7647,
#     'longitude': -106.2211,
#     'services': "{'amazon': 1, 'HBO MAX': 1, 'youtube': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-106.2211, 39.7647]}},
#   {'type': 'Feature',
#    'properties': {'age': 18,
#     'latitude': 40.8023,
#     'longitude': -90.4009,
#     'services': "{'Philo': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-90.4009, 40.8023]}},
#   {'type': 'Feature',
#    'properties': {'age': 72,
#     'latitude': 31.9973,
#     'longitude': -102.0779,
#     'services': "{'youtube': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-102.0779, 31.9973]}},
#   {'type': 'Feature',
#    'properties': {'age': 66,
#     'latitude': 32.8248,
#     'longitude': -97.4519,
#     'services': "{'netflix': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-97.4519, 32.8248]}},
#   {'type': 'Feature',
#    'properties': {'age': 76,
#     'latitude': 40.7143,
#     'longitude': -74.006,
#     'services': "{'netflix': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-74.006, 40.7143]}},
#   {'type': 'Feature',
#    'properties': {'age': 77,
#     'latitude': 43.6877,
#     'longitude': -123.2929,
#     'services': "{'hulu': 1, 'netflix': 1, 'Showtime': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-123.2929, 43.6877]}},
#   {'type': 'Feature',
#    'properties': {'age': 22,
#     'latitude': 43.8118,
#     'longitude': -71.1946,
#     'services': "{'youtube': 1, 'netflix': 1, 'Disney+': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-71.1946, 43.8118]}},
#   {'type': 'Feature',
#    'properties': {'age': 68,
#     'latitude': 32.8632,
#     'longitude': -97.3377,
#     'services': "{'netflix': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-97.3377, 32.8632]}},
#   {'type': 'Feature',
#    'properties': {'age': 59,
#     'latitude': 39.7505,
#     'longitude': -84.2686,
#     'services': "{'amazon': 1, 'youtube': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-84.2686, 39.7505]}},
#   {'type': 'Feature',
#    'properties': {'age': 61,
#     'latitude': 33.5429,
#     'longitude': -95.7416,
#     'services': "{'netflix': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-95.7416, 33.5429]}},
#   {'type': 'Feature',
#    'properties': {'age': 18,
#     'latitude': 35.9537,
#     'longitude': -84.8205,
#     'services': "{'netflix': 1, 'Tubi': 1, 'hulu': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-84.8205, 35.9537]}},
#   {'type': 'Feature',
#    'properties': {'age': 41,
#     'latitude': 41.4474,
#     'longitude': -71.6204,
#     'services': "{'youtube': 1, 'Discovery+': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-71.6204, 41.4474]}},
#   {'type': 'Feature',
#    'properties': {'age': 19,
#     'latitude': 36.0038,
#     'longitude': -93.2048,
#     'services': "{'youtube': 1, 'Crackle': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-93.2048, 36.0038]}},
#   {'type': 'Feature',
#    'properties': {'age': 21,
#     'latitude': 41.9362,
#     'longitude': -86.5543,
#     'services': "{'netflix': 1, 'youtube': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-86.5543, 41.9362]}},
#   {'type': 'Feature',
#    'properties': {'age': 29,
#     'latitude': 32.7204,
#     'longitude': -97.0826,
#     'services': "{'fuboTV': 1, 'netflix': 1, 'youtube': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-97.0826, 32.7204]}},
#   {'type': 'Feature',
#    'properties': {'age': 43,
#     'latitude': 42.9044,
#     'longitude': -90.442,
#     'services': "{'netflix': 1, 'Disney+': 1, 'hulu': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-90.442, 42.9044]}},
#   {'type': 'Feature',
#    'properties': {'age': 20,
#     'latitude': 45.6732,
#     'longitude': -97.0715,
#     'services': "{'HBO MAX': 1, 'amazon': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-97.0715, 45.6732]}},
#   {'type': 'Feature',
#    'properties': {'age': 21,
#     'latitude': 38.3983,
#     'longitude': -121.2303,
#     'services': "{'Discovery+': 1, 'hulu': 1, 'amazon': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-121.2303, 38.3983]}},
#   {'type': 'Feature',
#    'properties': {'age': 71,
#     'latitude': 40.1401,
#     'longitude': -87.9665,
#     'services': "{'Disney+': 1, 'fuboTV': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-87.9665, 40.1401]}},
#   {'type': 'Feature',
#    'properties': {'age': 51,
#     'latitude': 39.5296,
#     'longitude': -119.8138,
#     'services': "{'Crackle': 1, 'youtube': 1, 'amazon': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-119.8138, 39.5296]}},
#   {'type': 'Feature',
#    'properties': {'age': 19,
#     'latitude': 40.1318,
#     'longitude': -75.4596,
#     'services': "{'netflix': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-75.4596, 40.1318]}},
#   {'type': 'Feature',
#    'properties': {'age': 25,
#     'latitude': 26.7545,
#     'longitude': -82.2611,
#     'services': "{'netflix': 1, 'youtube': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-82.2611, 26.7545]}},
#   {'type': 'Feature',
#    'properties': {'age': 19,
#     'latitude': 27.5879,
#     'longitude': -99.2176,
#     'services': "{'fuboTV': 1, 'Showtime': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-99.2176, 27.5879]}},
#   {'type': 'Feature',
#    'properties': {'age': 41,
#     'latitude': 34.0303,
#     'longitude': -94.8986,
#     'services': "{'netflix': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-94.8986, 34.0303]}},
#   {'type': 'Feature',
#    'properties': {'age': 70,
#     'latitude': 36.5818,
#     'longitude': -90.2617,
#     'services': "{'netflix': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-90.2617, 36.5818]}},
#   {'type': 'Feature',
#    'properties': {'age': 64,
#     'latitude': 39.5611,
#     'longitude': -86.0723,
#     'services': "{'CBS All Access': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-86.0723, 39.5611]}},
#   {'type': 'Feature',
#    'properties': {'age': 31,
#     'latitude': 38.3498,
#     'longitude': -81.6326,
#     'services': "{'netflix': 1, 'fuboTV': 1, 'Disney+': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-81.6326, 38.3498]}},
#   {'type': 'Feature',
#    'properties': {'age': 49,
#     'latitude': 33.3022,
#     'longitude': -112.1226,
#     'services': "{'youtube': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-112.1226, 33.3022]}},
#   {'type': 'Feature',
#    'properties': {'age': 31,
#     'latitude': 41.937,
#     'longitude': -88.4202,
#     'services': "{'netflix': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-88.4202, 41.937]}},
#   {'type': 'Feature',
#    'properties': {'age': 30,
#     'latitude': 34.3454,
#     'longitude': -83.9505,
#     'services': "{'Philo': 1, 'Disney+': 1, 'youtube': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-83.9505, 34.3454]}},
#   {'type': 'Feature',
#    'properties': {'age': 69,
#     'latitude': 42.8956,
#     'longitude': -72.5097,
#     'services': "{'IMDb TV': 1, 'Philo': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-72.5097, 42.8956]}},
#   {'type': 'Feature',
#    'properties': {'age': 26,
#     'latitude': 47.8331,
#     'longitude': -121.6365,
#     'services': "{'NBC': 1, 'netflix': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-121.6365, 47.8331]}},
#   {'type': 'Feature',
#    'properties': {'age': 21,
#     'latitude': 32.2334,
#     'longitude': -86.2085,
#     'services': "{'netflix': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-86.2085, 32.2334]}},
#   {'type': 'Feature',
#    'properties': {'age': 21,
#     'latitude': 40.7177,
#     'longitude': -75.5335,
#     'services': "{'Apple TV+': 1, 'youtube': 1, 'netflix': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-75.5335, 40.7177]}},
#   {'type': 'Feature',
#    'properties': {'age': 28,
#     'latitude': 29.171,
#     'longitude': -83.0168,
#     'services': "{'netflix': 1, 'HBO MAX': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-83.0168, 29.171]}},
#   {'type': 'Feature',
#    'properties': {'age': 51,
#     'latitude': 32.9007,
#     'longitude': -95.8903,
#     'services': "{'Peacock': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-95.8903, 32.9007]}},
#   {'type': 'Feature',
#    'properties': {'age': 35,
#     'latitude': 30.5335,
#     'longitude': -92.0815,
#     'services': "{'netflix': 1, 'youtube': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-92.0815, 30.5335]}},
#   {'type': 'Feature',
#    'properties': {'age': 18,
#     'latitude': 41.0938,
#     'longitude': -85.0707,
#     'services': "{'youtube': 1, 'netflix': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-85.0707, 41.0938]}},
#   {'type': 'Feature',
#    'properties': {'age': 33,
#     'latitude': 31.6948,
#     'longitude': -106.3,
#     'services': "{'amazon': 1, 'youtube': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-106.3, 31.6948]}},
#   {'type': 'Feature',
#    'properties': {'age': 68,
#     'latitude': 38.3779,
#     'longitude': -96.6675,
#     'services': "{'netflix': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-96.6675, 38.3779]}},
#   {'type': 'Feature',
#    'properties': {'age': 26,
#     'latitude': 36.5901,
#     'longitude': -92.4162,
#     'services': "{'Disney+': 1, 'netflix': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-92.4162, 36.5901]}},
#   {'type': 'Feature',
#    'properties': {'age': 31,
#     'latitude': 26.5747,
#     'longitude': -80.0794,
#     'services': "{'Disney+': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-80.0794, 26.5747]}},
#   {'type': 'Feature',
#    'properties': {'age': 32,
#     'latitude': 40.4262,
#     'longitude': -97.3184,
#     'services': "{'Discovery+': 1, 'netflix': 1, 'youtube': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-97.3184, 40.4262]}},
#   {'type': 'Feature',
#    'properties': {'age': 65,
#     'latitude': 40.544,
#     'longitude': -84.3944,
#     'services': "{'youtube': 1, 'hulu': 1, 'Rent or Buy': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-84.3944, 40.544]}},
#   {'type': 'Feature',
#    'properties': {'age': 21,
#     'latitude': 37.147,
#     'longitude': -90.1795,
#     'services': "{'amazon': 1, 'netflix': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-90.1795, 37.147]}},
#   {'type': 'Feature',
#    'properties': {'age': 26,
#     'latitude': 40.9017,
#     'longitude': -94.2633,
#     'services': "{'Peacock': 1, 'netflix': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-94.2633, 40.9017]}},
#   {'type': 'Feature',
#    'properties': {'age': 65,
#     'latitude': 27.7522,
#     'longitude': -98.0697,
#     'services': "{'netflix': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-98.0697, 27.7522]}},
#   {'type': 'Feature',
#    'properties': {'age': 68,
#     'latitude': 35.2886,
#     'longitude': -89.488,
#     'services': "{'Crackle': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-89.488, 35.2886]}},
#   {'type': 'Feature',
#    'properties': {'age': 27,
#     'latitude': 38.2743,
#     'longitude': -121.9463,
#     'services': "{'hulu': 1, 'netflix': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-121.9463, 38.2743]}},
#   {'type': 'Feature',
#    'properties': {'age': 72,
#     'latitude': 48.9796,
#     'longitude': -97.5427,
#     'services': "{'Discovery+': 1, 'Peacock': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-97.5427, 48.9796]}},
#   {'type': 'Feature',
#    'properties': {'age': 61,
#     'latitude': 44.2773,
#     'longitude': -88.3976,
#     'services': "{'netflix': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-88.3976, 44.2773]}},
#   {'type': 'Feature',
#    'properties': {'age': 30,
#     'latitude': 40.7221,
#     'longitude': -74.0469,
#     'services': "{'amazon': 1, 'hulu': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-74.0469, 40.7221]}},
#   {'type': 'Feature',
#    'properties': {'age': 40,
#     'latitude': 37.3688,
#     'longitude': -76.7705,
#     'services': "{'Discovery+': 1, 'amazon': 1, 'hulu': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-76.7705, 37.3688]}},
#   {'type': 'Feature',
#    'properties': {'age': 41,
#     'latitude': 44.5402,
#     'longitude': -93.5805,
#     'services': "{'netflix': 1, 'amazon': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-93.5805, 44.5402]}},
#   {'type': 'Feature',
#    'properties': {'age': 61,
#     'latitude': 37.5808,
#     'longitude': -92.9309,
#     'services': "{'amazon': 1, 'netflix': 1, 'Apple TV+': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-92.9309, 37.5808]}},
#   {'type': 'Feature',
#    'properties': {'age': 27,
#     'latitude': 34.905,
#     'longitude': -116.8203,
#     'services': "{'Philo': 1, 'hulu': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-116.8203, 34.905]}},
#   {'type': 'Feature',
#    'properties': {'age': 23,
#     'latitude': 39.4776,
#     'longitude': -86.4668,
#     'services': "{'youtube': 1, 'netflix': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-86.4668, 39.4776]}},
#   {'type': 'Feature',
#    'properties': {'age': 49,
#     'latitude': 33.749,
#     'longitude': -84.38799999999998,
#     'services': "{'Crackle': 1, 'Starz': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-84.38799999999998, 33.749]}},
#   {'type': 'Feature',
#    'properties': {'age': 73,
#     'latitude': 34.2442,
#     'longitude': -84.8457,
#     'services': "{'hulu': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-84.8457, 34.2442]}},
#   {'type': 'Feature',
#    'properties': {'age': 68,
#     'latitude': 36.3249,
#     'longitude': -83.3142,
#     'services': "{'amazon': 1, 'netflix': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-83.3142, 36.3249]}},
#   {'type': 'Feature',
#    'properties': {'age': 19,
#     'latitude': 40.6497,
#     'longitude': -73.8824,
#     'services': "{'NBC': 1, 'netflix': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-73.8824, 40.6497]}},
#   {'type': 'Feature',
#    'properties': {'age': 25,
#     'latitude': 35.7551,
#     'longitude': -96.5658,
#     'services': "{'youtube': 1, 'Starz': 1, 'Philo': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-96.5658, 35.7551]}},
#   {'type': 'Feature',
#    'properties': {'age': 19,
#     'latitude': 38.2968,
#     'longitude': -81.5547,
#     'services': "{'netflix': 1, 'amazon': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-81.5547, 38.2968]}},
#   {'type': 'Feature',
#    'properties': {'age': 31,
#     'latitude': 37.5428,
#     'longitude': -122.5052,
#     'services': "{'hulu': 1, 'youtube': 1, 'netflix': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-122.5052, 37.5428]}},
#   {'type': 'Feature',
#    'properties': {'age': 48,
#     'latitude': 39.7803,
#     'longitude': -94.1024,
#     'services': "{'netflix': 1, 'youtube': 1, 'Disney+': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-94.1024, 39.7803]}},
#   {'type': 'Feature',
#    'properties': {'age': 63,
#     'latitude': 42.06399999999999,
#     'longitude': -86.4783,
#     'services': "{'CBS All Access': 1, 'youtube': 1}"},
#    'geometry': {'type': 'Point',
#     'coordinates': [-86.4783, 42.06399999999999]}},
#   {'type': 'Feature',
#    'properties': {'age': 59,
#     'latitude': 39.3476,
#     'longitude': -84.1181,
#     'services': "{'youtube': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-84.1181, 39.3476]}},
#   {'type': 'Feature',
#    'properties': {'age': 22,
#     'latitude': 41.0472,
#     'longitude': -75.3244,
#     'services': "{'FOX': 1, 'hulu': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-75.3244, 41.0472]}},
#   {'type': 'Feature',
#    'properties': {'age': 45,
#     'latitude': 38.0464,
#     'longitude': -84.4953,
#     'services': "{'netflix': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-84.4953, 38.0464]}},
#   {'type': 'Feature',
#    'properties': {'age': 27,
#     'latitude': 37.5556,
#     'longitude': -76.8237,
#     'services': "{'HBO MAX': 1, 'Philo': 1, 'IMDb TV': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-76.8237, 37.5556]}},
#   {'type': 'Feature',
#    'properties': {'age': 53,
#     'latitude': 59.8666,
#     'longitude': -158.5996,
#     'services': "{'netflix': 1, 'amazon': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-158.5996, 59.8666]}},
#   {'type': 'Feature',
#    'properties': {'age': 49,
#     'latitude': 40.9971,
#     'longitude': -76.0717,
#     'services': "{'Peacock': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-76.0717, 40.9971]}},
#   {'type': 'Feature',
#    'properties': {'age': 56,
#     'latitude': 40.3074,
#     'longitude': -79.5424,
#     'services': "{'amazon': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-79.5424, 40.3074]}},
#   {'type': 'Feature',
#    'properties': {'age': 77,
#     'latitude': 39.0997,
#     'longitude': -94.5786,
#     'services': "{'netflix': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-94.5786, 39.0997]}},
#   {'type': 'Feature',
#    'properties': {'age': 54,
#     'latitude': 28.9541,
#     'longitude': -95.3597,
#     'services': "{'hulu': 1, 'IMDb TV': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-95.3597, 28.9541]}},
#   {'type': 'Feature',
#    'properties': {'age': 39,
#     'latitude': 35.2132,
#     'longitude': -80.8231,
#     'services': "{'Peacock': 1, 'netflix': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-80.8231, 35.2132]}},
#   {'type': 'Feature',
#    'properties': {'age': 38,
#     'latitude': 38.4286,
#     'longitude': -82.3911,
#     'services': "{'youtube': 1, 'hulu': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-82.3911, 38.4286]}},
#   {'type': 'Feature',
#    'properties': {'age': 48,
#     'latitude': 40.2947,
#     'longitude': -81.1839,
#     'services': "{'CBS All Access': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-81.1839, 40.2947]}},
#   {'type': 'Feature',
#    'properties': {'age': 69,
#     'latitude': 30.4213,
#     'longitude': -87.2169,
#     'services': "{'netflix': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-87.2169, 30.4213]}},
#   {'type': 'Feature',
#    'properties': {'age': 76,
#     'latitude': 39.5676,
#     'longitude': -84.8161,
#     'services': "{'youtube': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-84.8161, 39.5676]}},
#   {'type': 'Feature',
#    'properties': {'age': 64,
#     'latitude': 36.5894,
#     'longitude': -79.0202,
#     'services': "{'amazon': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-79.0202, 36.5894]}},
#   {'type': 'Feature',
#    'properties': {'age': 31,
#     'latitude': 40.9265,
#     'longitude': -74.0392,
#     'services': "{'IMDb TV': 1, 'netflix': 1, 'youtube': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-74.0392, 40.9265]}},
#   {'type': 'Feature',
#    'properties': {'age': 40,
#     'latitude': 42.3389,
#     'longitude': -70.9196,
#     'services': "{'Philo': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-70.9196, 42.3389]}},
#   {'type': 'Feature',
#    'properties': {'age': 27,
#     'latitude': 43.4586,
#     'longitude': -83.9303,
#     'services': "{'netflix': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-83.9303, 43.4586]}},
#   {'type': 'Feature',
#    'properties': {'age': 55,
#     'latitude': 40.8689,
#     'longitude': -84.5904,
#     'services': "{'youtube': 1, 'netflix': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-84.5904, 40.8689]}},
#   {'type': 'Feature',
#    'properties': {'age': 43,
#     'latitude': 40.745,
#     'longitude': -88.5165,
#     'services': "{'netflix': 1, 'youtube': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-88.5165, 40.745]}},
#   {'type': 'Feature',
#    'properties': {'age': 79,
#     'latitude': 34.9412,
#     'longitude': -84.7645,
#     'services': "{'hulu': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-84.7645, 34.9412]}},
#   {'type': 'Feature',
#    'properties': {'age': 26,
#     'latitude': 47.1037,
#     'longitude': -122.3235,
#     'services': "{'youtube': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-122.3235, 47.1037]}},
#   {'type': 'Feature',
#    'properties': {'age': 30,
#     'latitude': 42.6392,
#     'longitude': -85.01100000000002,
#     'services': "{'PlutoTV': 1}"},
#    'geometry': {'type': 'Point',
#     'coordinates': [-85.01100000000002, 42.6392]}},
#   {'type': 'Feature',
#    'properties': {'age': 56,
#     'latitude': 32.4204,
#     'longitude': -85.0796,
#     'services': "{'Showtime': 1, 'youtube': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-85.0796, 32.4204]}},
#   {'type': 'Feature',
#    'properties': {'age': 58,
#     'latitude': 34.0294,
#     'longitude': -118.2871,
#     'services': "{'netflix': 1, 'youtube': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-118.2871, 34.0294]}},
#   {'type': 'Feature',
#    'properties': {'age': 45,
#     'latitude': 61.1549,
#     'longitude': -149.8866,
#     'services': "{'youtube': 1, 'amazon': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-149.8866, 61.1549]}},
#   {'type': 'Feature',
#    'properties': {'age': 19,
#     'latitude': 43.4426,
#     'longitude': -71.6491,
#     'services': "{'netflix': 1, 'amazon': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-71.6491, 43.4426]}},
#   {'type': 'Feature',
#    'properties': {'age': 71,
#     'latitude': 33.4228,
#     'longitude': -112.9528,
#     'services': "{'youtube': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-112.9528, 33.4228]}},
#   {'type': 'Feature',
#    'properties': {'age': 43,
#     'latitude': 38.8307,
#     'longitude': -77.2142,
#     'services': "{'youtube': 1, 'Apple TV+': 1, 'netflix': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-77.2142, 38.8307]}},
#   {'type': 'Feature',
#    'properties': {'age': 47,
#     'latitude': 40.6241,
#     'longitude': -84.2603,
#     'services': "{'hulu': 1, 'youtube': 1, 'fuboTV': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-84.2603, 40.6241]}},
#   {'type': 'Feature',
#    'properties': {'age': 41,
#     'latitude': 39.9259,
#     'longitude': -75.1196,
#     'services': "{'netflix': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-75.1196, 39.9259]}},
#   {'type': 'Feature',
#    'properties': {'age': 77,
#     'latitude': 28.5663,
#     'longitude': -81.2608,
#     'services': "{'netflix': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-81.2608, 28.5663]}},
#   {'type': 'Feature',
#    'properties': {'age': 46,
#     'latitude': 36.2092,
#     'longitude': -115.2941,
#     'services': "{'NBC': 1, 'netflix': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-115.2941, 36.2092]}},
#   {'type': 'Feature',
#    'properties': {'age': 53,
#     'latitude': 36.2345,
#     'longitude': -91.8154,
#     'services': "{'youtube': 1, 'netflix': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-91.8154, 36.2345]}},
#   {'type': 'Feature',
#    'properties': {'age': 37,
#     'latitude': 42.1522,
#     'longitude': -96.1822,
#     'services': "{'netflix': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-96.1822, 42.1522]}},
#   {'type': 'Feature',
#    'properties': {'age': 27,
#     'latitude': 44.3605,
#     'longitude': -112.1869,
#     'services': "{'hulu': 1, 'netflix': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-112.1869, 44.3605]}},
#   {'type': 'Feature',
#    'properties': {'age': 19,
#     'latitude': 40.4933,
#     'longitude': -81.9837,
#     'services': "{'netflix': 1, 'Showtime': 1, 'youtube': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-81.9837, 40.4933]}},
#   {'type': 'Feature',
#    'properties': {'age': 63,
#     'latitude': 39.1503,
#     'longitude': -77.0291,
#     'services': "{'amazon': 1, 'FOX': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-77.0291, 39.1503]}},
#   {'type': 'Feature',
#    'properties': {'age': 63,
#     'latitude': 42.0126,
#     'longitude': -79.4495,
#     'services': "{'hulu': 1, 'netflix': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-79.4495, 42.0126]}},
#   {'type': 'Feature',
#    'properties': {'age': 43,
#     'latitude': 30.8892,
#     'longitude': -90.4728,
#     'services': "{'amazon': 1, 'netflix': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-90.4728, 30.8892]}},
#   {'type': 'Feature',
#    'properties': {'age': 25,
#     'latitude': 36.0955,
#     'longitude': -78.4486,
#     'services': "{'youtube': 1, 'HBO MAX': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-78.4486, 36.0955]}},
#   {'type': 'Feature',
#    'properties': {'age': 42,
#     'latitude': 29.834,
#     'longitude': -95.4342,
#     'services': "{'hulu': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-95.4342, 29.834]}},
#   {'type': 'Feature',
#    'properties': {'age': 53,
#     'latitude': 31.2991,
#     'longitude': -87.0225,
#     'services': "{'Apple TV+': 1, 'youtube': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-87.0225, 31.2991]}},
#   {'type': 'Feature',
#    'properties': {'age': 31,
#     'latitude': 42.6424,
#     'longitude': -74.571,
#     'services': "{'Showtime': 1, 'amazon': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-74.571, 42.6424]}},
#   {'type': 'Feature',
#    'properties': {'age': 51,
#     'latitude': 38.2876,
#     'longitude': -86.0664,
#     'services': "{'PlutoTV': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-86.0664, 38.2876]}},
#   {'type': 'Feature',
#    'properties': {'age': 22,
#     'latitude': 31.8784,
#     'longitude': -86.3981,
#     'services': "{'youtube': 1, 'netflix': 1, 'hulu': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-86.3981, 31.8784]}},
#   {'type': 'Feature',
#    'properties': {'age': 51,
#     'latitude': 38.1753,
#     'longitude': -89.6479,
#     'services': "{'netflix': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-89.6479, 38.1753]}},
#   {'type': 'Feature',
#    'properties': {'age': 43,
#     'latitude': 32.608000000000004,
#     'longitude': -84.4574,
#     'services': "{'Philo': 1}"},
#    'geometry': {'type': 'Point',
#     'coordinates': [-84.4574, 32.608000000000004]}},
#   {'type': 'Feature',
# ...
#    'geometry': {'type': 'Point', 'coordinates': [-117.9132, 33.8356]}},
#   {'type': 'Feature',
#    'properties': {'age': 58,
#     'latitude': 45.5507,
#     'longitude': -67.7436,
#     'services': "{'hulu': 1, 'youtube': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-67.7436, 45.5507]}},
#   {'type': 'Feature',
#    'properties': {'age': 48,
#     'latitude': 41.3253,
#     'longitude': -78.3576,
#     'services': "{'netflix': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-78.3576, 41.3253]}},
#   {'type': 'Feature',
#    'properties': {'age': 57,
#     'latitude': 40.2662,
#     'longitude': -79.3984,
#     'services': "{'netflix': 1, 'Showtime': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-79.3984, 40.2662]}},
#   {'type': 'Feature',
#    'properties': {'age': 22,
#     'latitude': 37.4331,
#     'longitude': -82.9018,
#     'services': "{'amazon': 1, 'Apple TV+': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-82.9018, 37.4331]}},
#   {'type': 'Feature',
#    'properties': {'age': 27,
#     'latitude': 41.4948,
#     'longitude': -90.3907,
#     'services': "{'amazon': 1, 'youtube': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-90.3907, 41.4948]}},
#   {'type': 'Feature',
#    'properties': {'age': 46,
#     'latitude': 41.6583,
#     'longitude': -108.1517,
#     'services': "{'hulu': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-108.1517, 41.6583]}},
#   {'type': 'Feature',
#    'properties': {'age': 39,
#     'latitude': 41.1966,
#     'longitude': -97.5571,
#     'services': "{'Disney+': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-97.5571, 41.1966]}},
#   {'type': 'Feature',
#    'properties': {'age': 28,
#     'latitude': 40.76300000000001,
#     'longitude': -80.7042,
#     'services': "{'amazon': 1, 'netflix': 1}"},
#    'geometry': {'type': 'Point',
#     'coordinates': [-80.7042, 40.76300000000001]}},
#   {'type': 'Feature',
#    'properties': {'age': 43,
#     'latitude': 31.5599,
#     'longitude': -97.8456,
#     'services': "{'netflix': 1, 'youtube': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-97.8456, 31.5599]}},
#   {'type': 'Feature',
#    'properties': {'age': 49,
#     'latitude': 40.7742,
#     'longitude': -73.7189,
#     'services': "{'hulu': 1, 'netflix': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-73.7189, 40.7742]}},
#   {'type': 'Feature',
#    'properties': {'age': 49,
#     'latitude': 42.5065,
#     'longitude': -83.3484,
#     'services': "{'youtube': 1, 'amazon': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-83.3484, 42.5065]}},
#   {'type': 'Feature',
#    'properties': {'age': 32,
#     'latitude': 38.7049,
#     'longitude': -84.6237,
#     'services': "{'amazon': 1, 'hulu': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-84.6237, 38.7049]}},
#   {'type': 'Feature',
#    'properties': {'age': 36,
#     'latitude': 38.6208,
#     'longitude': -86.5899,
#     'services': "{'hulu': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-86.5899, 38.6208]}},
#   {'type': 'Feature',
#    'properties': {'age': 57,
#     'latitude': 37.6247,
#     'longitude': -122.429,
#     'services': "{'amazon': 1, 'youtube': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-122.429, 37.6247]}},
#   {'type': 'Feature',
#    'properties': {'age': 26,
#     'latitude': 41.7728,
#     'longitude': -87.9757,
#     'services': "{'Philo': 1, 'HBO MAX': 1, 'Rent or Buy': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-87.9757, 41.7728]}},
#   {'type': 'Feature',
#    'properties': {'age': 42,
#     'latitude': 41.8284,
#     'longitude': -93.9963,
#     'services': "{'netflix': 1, 'youtube': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-93.9963, 41.8284]}},
#   {'type': 'Feature',
#    'properties': {'age': 55,
#     'latitude': 38.3964,
#     'longitude': -84.2949,
#     'services': "{'youtube': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-84.2949, 38.3964]}},
#   {'type': 'Feature',
#    'properties': {'age': 41,
#     'latitude': 38.4455,
#     'longitude': -89.3069,
#     'services': "{'netflix': 1, 'youtube': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-89.3069, 38.4455]}},
#   {'type': 'Feature',
#    'properties': {'age': 37,
#     'latitude': 40.5727,
#     'longitude': -77.3761,
#     'services': "{'netflix': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-77.3761, 40.5727]}},
#   {'type': 'Feature',
#    'properties': {'age': 51,
#     'latitude': 27.8006,
#     'longitude': -97.3964,
#     'services': "{'amazon': 1, 'fuboTV': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-97.3964, 27.8006]}},
#   {'type': 'Feature',
#    'properties': {'age': 75,
#     'latitude': 35.7823,
#     'longitude': -94.4638,
#     'services': "{'hulu': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-94.4638, 35.7823]}},
#   {'type': 'Feature',
#    'properties': {'age': 40,
#     'latitude': 39.2847,
#     'longitude': -76.6205,
#     'services': "{'netflix': 1, 'HBO MAX': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-76.6205, 39.2847]}},
#   {'type': 'Feature',
#    'properties': {'age': 69,
#     'latitude': 31.6948,
#     'longitude': -106.3,
#     'services': "{'hulu': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-106.3, 31.6948]}},
#   {'type': 'Feature',
#    'properties': {'age': 32,
#     'latitude': 40.683,
#     'longitude': -76.2387,
#     'services': "{'amazon': 1, 'netflix': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-76.2387, 40.683]}},
#   {'type': 'Feature',
#    'properties': {'age': 78,
#     'latitude': 38.859,
#     'longitude': -77.0997,
#     'services': "{'Disney+': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-77.0997, 38.859]}},
#   {'type': 'Feature',
#    'properties': {'age': 27,
#     'latitude': 36.9709,
#     'longitude': -93.718,
#     'services': "{'Apple TV+': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-93.718, 36.9709]}},
#   {'type': 'Feature',
#    'properties': {'age': 53,
#     'latitude': 37.7807,
#     'longitude': -80.39399999999998,
#     'services': "{'Starz': 1}"},
#    'geometry': {'type': 'Point',
#     'coordinates': [-80.39399999999998, 37.7807]}},
#   {'type': 'Feature',
#    'properties': {'age': 25,
#     'latitude': 39.3923,
#     'longitude': -76.4132,
#     'services': "{'youtube': 1, 'CBS All Access': 1, 'netflix': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-76.4132, 39.3923]}},
#   {'type': 'Feature',
#    'properties': {'age': 79,
#     'latitude': 40.6845,
#     'longitude': -81.1838,
#     'services': "{'Crackle': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-81.1838, 40.6845]}},
#   {'type': 'Feature',
#    'properties': {'age': 30,
#     'latitude': 33.4491,
#     'longitude': -112.1972,
#     'services': "{'Philo': 1, 'Apple TV+': 1, 'amazon': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-112.1972, 33.4491]}},
#   {'type': 'Feature',
#    'properties': {'age': 45,
#     'latitude': 44.0955,
#     'longitude': -71.1194,
#     'services': "{'youtube': 1, 'Showtime': 1, 'CBS All Access': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-71.1194, 44.0955]}},
#   {'type': 'Feature',
#    'properties': {'age': 44,
#     'latitude': 38.9784,
#     'longitude': -79.9494,
#     'services': "{'netflix': 1, 'hulu': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-79.9494, 38.9784]}},
#   {'type': 'Feature',
#    'properties': {'age': 65,
#     'latitude': 34.2445,
#     'longitude': -97.967,
#     'services': "{'hulu': 1, 'Discovery+': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-97.967, 34.2445]}},
#   {'type': 'Feature',
#    'properties': {'age': 55,
#     'latitude': 32.9468,
#     'longitude': -94.2539,
#     'services': "{'netflix': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-94.2539, 32.9468]}},
#   {'type': 'Feature',
#    'properties': {'age': 39,
#     'latitude': 32.7153,
#     'longitude': -117.1573,
#     'services': "{'hulu': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-117.1573, 32.7153]}},
#   {'type': 'Feature',
#    'properties': {'age': 67,
#     'latitude': 43.0246,
#     'longitude': -77.7743,
#     'services': "{'netflix': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-77.7743, 43.0246]}},
#   {'type': 'Feature',
#    'properties': {'age': 20,
#     'latitude': 27.9125,
#     'longitude': -97.1884,
#     'services': "{'youtube': 1, 'netflix': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-97.1884, 27.9125]}},
#   {'type': 'Feature',
#    'properties': {'age': 29,
#     'latitude': 35.1371,
#     'longitude': -76.7406,
#     'services': "{'youtube': 1, 'netflix': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-76.7406, 35.1371]}},
#   {'type': 'Feature',
#    'properties': {'age': 36,
#     'latitude': 36.9663,
#     'longitude': -86.3933,
#     'services': "{'Disney+': 1, 'Philo': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-86.3933, 36.9663]}},
#   {'type': 'Feature',
#    'properties': {'age': 59,
#     'latitude': 43.0389,
#     'longitude': -87.9065,
#     'services': "{'netflix': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-87.9065, 43.0389]}},
#   {'type': 'Feature',
#    'properties': {'age': 18,
#     'latitude': 33.7866,
#     'longitude': -118.2987,
#     'services': "{'amazon': 1, 'netflix': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-118.2987, 33.7866]}},
#   {'type': 'Feature',
#    'properties': {'age': 64,
#     'latitude': 44.4976,
#     'longitude': -71.9505,
#     'services': "{'CBS All Access': 1, 'HBO MAX': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-71.9505, 44.4976]}},
#   {'type': 'Feature',
#    'properties': {'age': 21,
#     'latitude': 45.3583,
#     'longitude': -95.2049,
#     'services': "{'netflix': 1, 'Discovery+': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-95.2049, 45.3583]}},
#   {'type': 'Feature',
#    'properties': {'age': 27,
#     'latitude': 38.9311,
#     'longitude': -89.2463,
#     'services': "{'netflix': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-89.2463, 38.9311]}},
#   {'type': 'Feature',
#    'properties': {'age': 73,
#     'latitude': 37.8274,
#     'longitude': -87.5632,
#     'services': "{'CBS All Access': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-87.5632, 37.8274]}},
#   {'type': 'Feature',
#    'properties': {'age': 79,
#     'latitude': 33.8444,
#     'longitude': -84.4741,
#     'services': "{'hulu': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-84.4741, 33.8444]}},
#   {'type': 'Feature',
#    'properties': {'age': 64,
#     'latitude': 47.2643,
#     'longitude': -122.4575,
#     'services': "{'Showtime': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-122.4575, 47.2643]}},
#   {'type': 'Feature',
#    'properties': {'age': 48,
#     'latitude': 45.1635,
#     'longitude': -98.3193,
#     'services': "{'netflix': 1, 'hulu': 1, 'Philo': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-98.3193, 45.1635]}},
#   {'type': 'Feature',
#    'properties': {'age': 62,
#     'latitude': 39.7117,
#     'longitude': -84.0233,
#     'services': "{'youtube': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-84.0233, 39.7117]}},
#   {'type': 'Feature',
#    'properties': {'age': 40,
#     'latitude': 43.6135,
#     'longitude': -116.2035,
#     'services': "{'Apple TV+': 1, 'youtube': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-116.2035, 43.6135]}},
#   {'type': 'Feature',
#    'properties': {'age': 31,
#     'latitude': 44.98,
#     'longitude': -93.2638,
#     'services': "{'Starz': 1, 'netflix': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-93.2638, 44.98]}},
#   {'type': 'Feature',
#    'properties': {'age': 51,
#     'latitude': 33.0534,
#     'longitude': -116.5658,
#     'services': "{'youtube': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-116.5658, 33.0534]}},
#   {'type': 'Feature',
#    'properties': {'age': 71,
#     'latitude': 33.8444,
#     'longitude': -84.4741,
#     'services': "{'Showtime': 1, 'netflix': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-84.4741, 33.8444]}},
#   {'type': 'Feature',
#    'properties': {'age': 44,
#     'latitude': 40.0427,
#     'longitude': -76.4277,
#     'services': "{'netflix': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-76.4277, 40.0427]}},
#   {'type': 'Feature',
#    'properties': {'age': 38,
#     'latitude': 42.4906,
#     'longitude': -78.8499,
#     'services': "{'HBO MAX': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-78.8499, 42.4906]}},
#   {'type': 'Feature',
#    'properties': {'age': 62,
#     'latitude': 33.5631,
#     'longitude': -117.2738,
#     'services': "{'Starz': 1, 'netflix': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-117.2738, 33.5631]}},
#   {'type': 'Feature',
#    'properties': {'age': 72,
#     'latitude': 40.5973,
#     'longitude': -96.0241,
#     'services': "{'youtube': 1, 'amazon': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-96.0241, 40.5973]}},
#   {'type': 'Feature',
#    'properties': {'age': 43,
#     'latitude': 34.0831,
#     'longitude': -117.2711,
#     'services': "{'Discovery+': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-117.2711, 34.0831]}},
#   {'type': 'Feature',
#    'properties': {'age': 38,
#     'latitude': 37.1911,
#     'longitude': -82.6513,
#     'services': "{'Discovery+': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-82.6513, 37.1911]}},
#   {'type': 'Feature',
#    'properties': {'age': 79,
#     'latitude': 32.7078,
#     'longitude': -82.5274,
#     'services': "{'youtube': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-82.5274, 32.7078]}},
#   {'type': 'Feature',
#    'properties': {'age': 78,
#     'latitude': 34.9576,
#     'longitude': -83.3901,
#     'services': "{'netflix': 1, 'youtube': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-83.3901, 34.9576]}},
#   {'type': 'Feature',
#    'properties': {'age': 22,
#     'latitude': 41.0491,
#     'longitude': -85.1462,
#     'services': "{'netflix': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-85.1462, 41.0491]}},
#   {'type': 'Feature',
#    'properties': {'age': 67,
#     'latitude': 43.894,
#     'longitude': -73.203,
#     'services': "{'hulu': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-73.203, 43.894]}},
#   {'type': 'Feature',
#    'properties': {'age': 20,
#     'latitude': 41.8439,
#     'longitude': -79.145,
#     'services': "{'youtube': 1, 'HBO MAX': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-79.145, 41.8439]}},
#   {'type': 'Feature',
#    'properties': {'age': 34,
#     'latitude': 36.9331,
#     'longitude': -94.873,
#     'services': "{'amazon': 1, 'youtube': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-94.873, 36.9331]}},
#   {'type': 'Feature',
#    'properties': {'age': 70,
#     'latitude': 39.9723,
#     'longitude': -75.0607,
#     'services': "{'hulu': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-75.0607, 39.9723]}},
#   {'type': 'Feature',
#    'properties': {'age': 67,
#     'latitude': 38.9756,
#     'longitude': -92.5079,
#     'services': "{'hulu': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-92.5079, 38.9756]}},
#   {'type': 'Feature',
#    'properties': {'age': 66,
#     'latitude': 27.0595,
#     'longitude': -80.1364,
#     'services': "{'youtube': 1, 'netflix': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-80.1364, 27.0595]}},
#   {'type': 'Feature',
#    'properties': {'age': 74,
#     'latitude': 38.5574,
#     'longitude': -78.9227,
#     'services': "{'netflix': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-78.9227, 38.5574]}},
#   {'type': 'Feature',
#    'properties': {'age': 41,
#     'latitude': 41.8966,
#     'longitude': -76.5328,
#     'services': "{'Philo': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-76.5328, 41.8966]}},
#   {'type': 'Feature',
#    'properties': {'age': 68,
#     'latitude': 33.6706,
#     'longitude': -83.874,
#     'services': "{'Showtime': 1, 'Disney+': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-83.874, 33.6706]}},
#   {'type': 'Feature',
#    'properties': {'age': 27,
#     'latitude': 34.1083,
#     'longitude': -117.2898,
#     'services': "{'youtube': 1, 'HBO MAX': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-117.2898, 34.1083]}},
#   {'type': 'Feature',
#    'properties': {'age': 54,
#     'latitude': 41.662,
#     'longitude': -86.1586,
#     'services': "{'NBC': 1, 'Disney+': 1}"},
#    'geometry': {'type': 'Point', 'coordinates': [-86.1586, 41.662]}},
#   ...]}

# %%
useful_columns = ['age','latitude', 'longitude','services']
geojson_dict = df_to_geojson(df_geo, properties=useful_columns)
geojson_str = json.dumps(geojson_dict, indent=2)

# %%
output_filename = 'dataset.js'
with open(output_filename, 'w') as output_file:
    output_file.write('var dataset = {};'.format(geojson_str))

# %%
# how many features did we save to the geojson file?
print('{} geotagged features saved to file'.format(len(geojson_dict['features'])))
# Out:
# 9515 geotagged features saved to file
